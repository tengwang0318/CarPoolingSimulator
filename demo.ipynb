# %%
import pandas as pd

# %%
df = pd.read_csv("data/data20161101/gps_20161101.csv")

# %%
df.head()
# Out:
#    rzg@oxovmhz-FzC3vzryg2dxtAsft8Iw  mto@luyuffA3FAvckpqngarDtAnhA4DD  \
# 0  rzg@oxovmhz-FzC3vzryg2dxtAsft8Iw  mto@luyuffA3FAvckpqngarDtAnhA4DD
# 1  rzg@oxovmhz-FzC3vzryg2dxtAsft8Iw  mto@luyuffA3FAvckpqngarDtAnhA4DD
# 2  rzg@oxovmhz-FzC3vzryg2dxtAsft8Iw  mto@luyuffA3FAvckpqngarDtAnhA4DD
# 3  rzg@oxovmhz-FzC3vzryg2dxtAsft8Iw  mto@luyuffA3FAvckpqngarDtAnhA4DD
# 4  rzg@oxovmhz-FzC3vzryg2dxtAsft8Iw  mto@luyuffA3FAvckpqngarDtAnhA4DD
#
#    1477969147  104.07513  30.72724
# 0  1477969150  104.07513  30.72702
# 1  1477969154  104.07504  30.72672
# 2  1477969156  104.07497  30.72630
# 3  1477969159  104.07497  30.72582
# 4  1477969162  104.07496  30.72544

# %%
import pickle
pickle_file_path = "data/chengdu_order.pickle"

# %%
with open(pickle_file_path,"rb") as f:
    data = pickle.load(f)

# %%
sorted(data.keys())
# Out:
# [120,
#  180,
#  240,
#  300,
#  360,
#  420,
#  480,
#  540,
#  600,
#  660,
#  720,
#  780,
#  840,
#  900,
#  960,
#  1020,
#  1080,
#  1140,
#  1200,
#  1260,
#  1320,
#  1380,
#  1440,
#  1500,
#  1560,
#  1620,
#  1680,
#  1740,
#  1800,
#  1860,
#  1920,
#  1980,
#  2040,
#  2100,
#  2160,
#  2220,
#  2280,
#  2340,
#  2400,
#  2460,
#  2520,
#  2580,
#  2640,
#  2700,
#  2760,
#  2820,
#  2880,
#  2940,
#  3000,
#  3060,
#  3120,
#  3180,
#  3240,
#  3300,
#  3360,
#  3420,
#  3480,
#  3540,
#  3600,
#  3660,
#  3720,
#  3780,
#  3840,
#  3900,
#  3960,
#  4020,
#  4080,
#  4140,
#  4200,
#  4260,
#  4320,
#  4380,
#  4440,
#  4500,
#  4560,
#  4620,
#  4680,
#  4740,
#  4800,
#  4860,
#  4920,
#  4980,
#  5040,
#  5100,
#  5160,
#  5220,
#  5280,
#  5340,
#  5400,
#  5460,
#  5520,
#  5580,
#  5640,
#  5700,
#  5760,
#  5820,
#  5880,
#  5940,
#  6000,
#  6060,
#  6120,
#  6180,
#  6240,
#  6300,
#  6360,
#  6420,
#  6480,
#  6540,
#  6600,
#  6660,
#  6720,
#  6780,
# ...

# %%
print(data.values())

# %%
for key, val in data.items():
    print(key,val)
    break

# %%
data[120][5]
# Out:
# [28,
#  5602701361,
#  30.674943,
#  104.0815781,
#  1159516133,
#  30.6468439,
#  104.0784216,
#  4.039714244202278,
#  120,
#  65,
#  65,
#  [5602701361,
#   8240040765,
#   2653571754,
#   1958204265,
#   1958204318,
#   6814327929,
#   1458972939,
#   1192818260,
#   4414330240,
#   1159136172,
#   6356151544,
#   1156126849,
#   5213238557,
#   5514341246,
#   5530209135,
#   5530209137,
#   5530209138,
#   5530209130,
#   5530209125,
#   4521001284,
#   5530209123,
#   5530208215,
#   1156126844,
#   1159156115,
#   3742070447,
#   5530209388,
#   3742070439,
#   1301933028,
#   1301932970,
#   1159516133],
#  [0.1424973523039361,
#   0.06320916148851406,
#   0.09177179765098249,
#   0.6888102043648628,
#   0.20726024760558498,
#   0.5725378781293282,
#   0.018290946072946523,
#   0.18197265921539263,
#   0.2591779225436642,
#   0.00857801721340336,
#   0.3187345482960876,
#   0.171482768447883,
#   0.013055996925058612,
#   0.031205618257398655,
#   0.07494409461408921,
# ...
